# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd
#it is dictionary below
data={
    "Name":["shyam","ram","ghamshyam"],
    "age":[15,None,30],
    "salary":[50000,30000,None]
}
df =pd.DataFrame(data)
print(df)
print(df.isnull().sum())
df_drop=df.dropna()
print(df_drop)
df["age"].fillna(df["age"].mean(),inplace=True)
df["salary"].fillna(df["salary"].mean(),inplace=True)
print(df)
print(df.isnull().mean()*100)
# Out:
#         Name   age   salary
# 0      shyam  15.0  50000.0
# 1        ram   NaN  30000.0
# 2  ghamshyam  30.0      NaN
# Name      0
# age       1
# salary    1
# dtype: int64
#     Name   age   salary
# 0  shyam  15.0  50000.0
#         Name   age   salary
# 0      shyam  15.0  50000.0
# 1        ram   NaN  30000.0
# 2  ghamshyam  30.0      NaN
# Name       0.000000
# age       33.333333
# salary    33.333333
# dtype: float64
# /tmp/ipykernel_57921/3615481631.py:12: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["age"].fillna(df["age"].mean(),inplace=True)
# /tmp/ipykernel_57921/3615481631.py:13: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["salary"].fillna(df["salary"].mean(),inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

import pandas as pd

df = pd.read_csv("sampple_data.csv")

df_label = df.copy()

le = LabelEncoder()

df_label['Gender_Encoded']=le.fit_transform(df_label['Gender'])

print('\n Label encoded data')

print(df_label[['Name','Gender','Gender_Encoded']].head(5))

df_encoded = pd.get_dummies(df_label,columns=['City'],dtype=int)

print('\n hot encoded data city')

print(df_encoded)
# Out:
#  Label encoded data
#      Name  Gender  Gender_Encoded
# 0    Aman    Male               1
# 1   Priya  Female               0
# 2   Rahul    Male               1
# 3  Anjali  Female               0
# 4    Ravi    Male               1
#
#  hot encoded data city
#       Name  Gender Passed  Gender_Encoded  City_Bangalore  City_Chennai  \
# 0     Aman    Male    Yes               1               0             0
# 1    Priya  Female    Yes               0               0             0
# 2    Rahul    Male     No               1               1             0
# 3   Anjali  Female    Yes               0               0             0
# 4     Ravi    Male    Yes               1               0             0
# 5    Meera  Female     No               0               0             1
# 6    Arjun    Male    Yes               1               1             0
# 7     Neha  Female    Yes               0               0             0
# 8    Imran    Male     No               1               0             1
# 9    Sneha  Female    Yes               0               0             0
# 10     Raj    Male    Yes               1               0             1
# 11   Divya  Female     No               0               0             0
# 12   Kabir    Male    Yes               1               0             0
# 13  Simran  Female    Yes               0               1             0
# 14   Karan    Male     No               1               0             0
# 15   Pooja  Female    Yes               0               0             0
# 16  Rakesh    Male    Yes               1               0             1
# 17    Isha  Female     No               0               0             0
# 18   Rohit    Male    Yes               1               0             0
# 19   Deepa  Female    Yes               0               1             0
#
#     City_Delhi  City_Mumbai
# 0            1            0
# 1            0            1
# 2            0            0
# 3            0            1
# 4            1            0
# 5            0            0
# 6            0            0
# 7            1            0
# 8            0            0
# 9            0            1
# 10           0            0
# 11           1            0
# 12           0            1
# 13           0            0
# 14           1            0
# 15           0            1
# 16           0            0
# 17           1            0
# 18           1            0
# 19           0            0

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform()
scaler = scaler.fit_transform()
x_scaler = scaler.fit_transform

# %%
# Create Data
#      ↓
# Convert to DataFrame
#      ↓
# Standard Scaling
#      ↓
# MinMax Scaling
#      ↓
# Separate X and y
#      ↓
# Split into Train/Test
#      ↓
# Print Results

import pandas as pd

from sklearn.preprocessing import StandardScaler,MinMaxScaler

from sklearn.model_selection import train_test_split


data = {
    
    'studyhour': [1, 2, 3, 4, 5],
    
    'testscore': [40, 50, 60, 70, 80]
    
}

df = pd.DataFrame(data)


# Standard Scaler
scaler = StandardScaler()

scaled_data = scaler.fit_transform(df)

print("Standard Scaler Output:")

print(pd.DataFrame(scaled_data, columns=df.columns))

minmax_scaler = MinMaxScaler()

minmax_scaled = minmax_scaler.fit_transform(df)

print("\n minmax scaled output")

print(pd.DataFrame(minmax_scaled,columns=["studyhour","testscore"]))

X = df[['studyhour']]

y = df[['testscore']]

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=40)

#x train aur y train hai 
print("traning data")

print(X_train)

print("test_data")

print(X_test)
# Out:
# Standard Scaler Output:
#    studyhour  testscore
# 0  -1.414214  -1.414214
# 1  -0.707107  -0.707107
# 2   0.000000   0.000000
# 3   0.707107   0.707107
# 4   1.414214   1.414214
#
#  minmax scaled output
#    studyhour  testscore
# 0       0.00       0.00
# 1       0.25       0.25
# 2       0.50       0.50
# 3       0.75       0.75
# 4       1.00       1.00
# traning data
#    studyhour
# 0          1
# 1          2
# 4          5
# 3          4
# test_data
#    studyhour
# 2          3
